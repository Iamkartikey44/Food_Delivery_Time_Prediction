# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
#Load Data
df = pd.read_csv("swiggy.csv")
df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
#Shape of data
rows,cols =df.shape

print(f"The dataset has {rows} and {cols} columns")
# Out:
# The dataset has 45593 and 20 columns

# %%
#Datatypes of columns
df.dtypes.rename("Data Types")
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# Name: Data Types, dtype: object

# %% [markdown]
# **Data_Type**: object

# %%
#Info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
# ...

# %% [markdown]
# ## 🔧 Data Type Corrections
#
# <div style="background-color:#1e293b; padding:12px; border-left:6px solid #8ecae6; border-radius:6px; margin-bottom:10px;">
# 🔵 <b>Age</b><br>
# <span style="color:#8ecae6;">The <i>Age</i> column should be converted to a <b>numerical</b> data type.</span>
# </div>
#
# <div style="background-color:#1e293b; padding:12px; border-left:6px solid #90db8a; border-radius:6px; margin-bottom:10px;">
# 🟢 <b>Ratings</b><br>
# <span style="color:#90db8a;">The <i>Ratings</i> column should be stored as a <b>float</b>.</span>
# </div>
#
# <div style="background-color:#1e293b; padding:12px; border-left:6px solid #ffd166; border-radius:6px; margin-bottom:10px;">
# 🟡 <b>Date & Time</b><br>
# <span style="color:#ffd166;">The <i>Date</i> and <i>Time</i> columns should be converted to proper <b>date</b> and <b>time</b> formats.</span>
# </div>
#
# <div style="background-color:#1e293b; padding:12px; border-left:6px solid #cdb4db; border-radius:6px; margin-bottom:10px;">
# 🟣 <b>Vehicle Condition</b><br>
# <span style="color:#cdb4db;">The <i>Vehicle Condition</i> column appears to be <b>categorical</b> and is currently <b>integer-encoded</b>.</span>
# </div>
#
# <div style="background-color:#1e293b; padding:12px; border-left:6px solid #ffb703; border-radius:6px; margin-bottom:10px;">
# 🟠 <b>Multiple Deliveries</b><br>
# <span style="color:#ffb703;">The <i>Multiple Deliveries</i> column should be an <b>integer</b> data type.</span>
# </div>
#
# <div style="background-color:#1e293b; padding:12px; border-left:6px solid #f28482; border-radius:6px;">
# 🔴 <b>Target Columns</b><br>
# <span style="color:#f28482;">All <i>target</i> columns should be stored as <b>numerical</b> values.</span>
# </div>

# %%
#Missing values in data
df.isna().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %% [markdown]
# <span style="background-color:#0f5132; color:#a7f3d0; padding:4px 10px; border-radius:999px;">
# ✔ No missing values in the data
# </span>

# %%
#Sample 50 rows of data for viewing(NaN values in the data)
df.sample(50)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 32135  0xdfbb     DEHRES010DEL03                   35                       5
# 23430  0x6a23   RANCHIRES09DEL03                   37                     4.7
# 21472  0x5ccd     PUNERES08DEL01                   39                     4.8
# 1613   0x62f2      HYDRES20DEL02                   31                     3.5
# 7395   0x1c37      MYSRES17DEL02                   39                     4.9
# 11190  0xca83     AURGRES17DEL03                   29                     4.5
# 30586  0x9b77      JAPRES17DEL01                   27                     4.4
# 7689   0x1914     CHENRES16DEL02                   39                     4.3
# 10035  0x49b9   RANCHIRES20DEL01                   22                     4.6
# 8958   0x19e8      MUMRES06DEL02                   29                     4.7
# 28413  0x7929      SURRES08DEL01                   36                     4.3
# ...

# %% [markdown]
# ## Missing Values
#
# **`Missing values are string type in the data with an extra space.`**

# %%
#17999,43317
df.loc[17999]
# Out:
# ID                                      0x437
# Delivery_person_ID             BANGRES13DEL02
# Delivery_person_Age                       NaN
# Delivery_person_Ratings                   NaN
# Restaurant_latitude                 -12.935662
# Restaurant_longitude                 -77.61413
# Delivery_location_latitude           12.985662
# Delivery_location_longitude           77.66413
# Order_Date                          11-03-2022
# Time_Orderd                               NaN
# Time_Order_picked                     18:55:00
# Weatherconditions               conditions NaN
# Road_traffic_density                      NaN
# Vehicle_condition                            3
# Type_of_order                           Snack
# Type_of_vehicle                       scooter
# multiple_deliveries                          1
# Festival                                   No
# City                            Metropolitian
# Time_taken(min)                       (min) 21
# Name: 17999, dtype: object

# %%
# column wise string NaNs
(df=="NaN ").sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
(df=="NaN ").sum().sum()
# Out:
# np.int64(8515)

# %%
# replace string NaN with NaN
df.replace("NaN ",np.nan)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
#verify missing values in the data
df.replace("NaN ",np.nan).isna().sum().sum()
# Out:
# np.int64(8515)

# %%
#Verified that string NaNs converted to Nan
df.loc[:,"Weatherconditions"].str.replace("conditions ","").replace("NaN",np.nan).isna().sum()
# Out:
# np.int64(616)

# %% [markdown]
# <span style="background-color:#1f2937; color:#fbbf24; padding:4px 10px; border-radius:999px;">
# ✔ 616 missing values in the weather column
# </span>

# %%
#DataFrame with all the missing values replace
missing_df = (
    df.replace("NaN ",np.nan)
    .assign(
        Weatherconditions = lambda df_ : (
            df_['Weatherconditions']
            .str.replace("conditions ","")
            .replace("NaN",np.nan)
            )
    )
)

# %%
missing_df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
missing_df.isna().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
# total missing values in data
missing_df.isna().sum().sum()
# Out:
# np.int64(9131)

# %%
#8515(replace with np.nan) + 616(np.nan) =9131

# %%
# missing values matrix
msno.matrix(missing_df)
# Out:
# <Axes: >

# %%
# bar plot for columns having missing data
msno.bar(missing_df)
# Out:
# <Axes: >

# %%
# missing data correlation
msno.heatmap(missing_df)
# Out:
# <Axes: >

# %% [markdown]
# ## 🔍 Observations from Missingness Correlation
#
# <div style="background-color:#1f2937; padding:12px; border-left:5px solid #60a5fa; border-radius:6px; margin-bottom:10px;">
# 🔵 <b>Delivery Person Attributes</b><br>
# <span style="color:#93c5fd;">
# The delivery person–related columns (such as <i>Age</i> and <i>Ratings</i>) show a strong correlation in missingness.
# This indicates that when one rider-related attribute is missing, other rider details are also likely missing, suggesting
# a lack of rider data capture rather than independent issues.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:12px; border-left:5px solid #a78bfa; border-radius:6px; margin-bottom:10px;">
# 🟣 <b>Time Ordered vs Rider Data</b><br>
# <span style="color:#c4b5fd;">
# The <i>Time Ordered</i> column also shows correlation with rider-related fields. This suggests that missing values may be caused
# by system or network failures where the application was unable to log both the rider information and the order time simultaneously.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:12px; border-left:5px solid #34d399; border-radius:6px; margin-bottom:10px;">
# 🟢 <b>Weather Conditions & Road Traffic Density</b><br>
# <span style="color:#6ee7b7;">
# There is a very high correlation in missingness between <i>Weather Conditions</i> and <i>Road Traffic Density</i>.
# <b>This does NOT imply that weather and traffic are correlated in value.</b>
# Instead, it indicates that when data is missing in one column, it is highly likely to be missing in the other as well.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:12px; border-left:5px solid #fbbf24; border-radius:6px;">
# 🟠 <b>Road Traffic Density & Rider Dependency</b><br>
# <span style="color:#fde68a;">
# Road traffic density also shows missingness correlation with rider-related columns, which may suggest that this information
# is collected or transmitted through the rider’s device. This hypothesis requires further investigation.
# </span>
# </div>

# %%
missing_df[["Weatherconditions","Road_traffic_density"]].isna().sum()
# Out:
# Weatherconditions       616
# Road_traffic_density    601
# dtype: int64

# %%
# prove point of missingness
(
    missing_df[["Weatherconditions","Road_traffic_density"]]
    .isna().all(axis=1)
    .sum()
) /  missing_df[["Weatherconditions","Road_traffic_density"]].isna().sum()
# Out:
# Weatherconditions       0.975649
# Road_traffic_density    1.000000
# dtype: float64

# %%
# dendrogram of missingness
msno.dendrogram(missing_df)
# Out:
# <Axes: >

# %% [markdown]
# ## 🌳 Missingness Dendrogram
#
# <div style="background-color:#1f2937; padding:10px; border-left:5px solid #60a5fa; border-radius:6px; margin-bottom:8px;">
# 🔵 <b>Clustered Missingness</b><br>
# <span style="color:#93c5fd;">
# The dendrogram groups columns based on similarity in their missing value patterns.
# Columns joined at lower heights indicate that their missing values occur together frequently.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:10px; border-left:5px solid #a78bfa; border-radius:6px; margin-bottom:8px;">
# 🟣 <b>Delivery Person Attributes</b><br>
# <span style="color:#c4b5fd;">
# <i>Delivery_person_Age</i> and <i>Delivery_person_Ratings</i> are closely clustered, showing that rider-related information
# is often missing simultaneously, suggesting incomplete rider data capture.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:10px; border-left:5px solid #34d399; border-radius:6px; margin-bottom:8px;">
# 🟢 <b>Order Time Dependency</b><br>
# <span style="color:#6ee7b7;">
# The <i>Time_Ordered</i> column clusters with rider attributes, indicating that order timing data may be lost during
# the same events when rider information is not recorded, possibly due to system or network issues.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:10px; border-left:5px solid #fbbf24; border-radius:6px; margin-bottom:8px;">
# 🟠 <b>Weather & Traffic Information</b><br>
# <span style="color:#fde68a;">
# <i>Weatherconditions</i> and <i>Road_traffic_density</i> form a strong cluster, meaning their missing values occur together.
# This reflects shared data sourcing rather than a relationship between their actual values.
# </span>
# </div>
#
# <div style="background-color:#1f2937; padding:10px; border-left:5px solid #f87171; border-radius:6px;">
# 🔴 <b>Independent Columns</b><br>
# <span style="color:#fecaca;">
# Core fields such as location coordinates, order identifiers, and target variables appear isolated in the dendrogram,
# indicating minimal or no missing values and independent data availability.
# </span>
# </div>

# %%
# percentage of rows in the data having missing value
(missing_df.isna().any(axis=1).sum() / missing_df.shape[0]) * 100
# Out:
# np.float64(9.266773408198627)

# %% [markdown]
# **About 9% of the rows in the data have missing values**

# %%
df.columns.tolist()
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weatherconditions',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken(min)']

# %%
def change_column_names(data: pd.DataFrame):
    return (
        data.rename(str.lower,axis=1)
        .rename({
            "delivery_person_id" : "rider_id",
            "delivery_person_age": "age",
            "delivery_person_ratings": "ratings",
            "delivery_location_latitude": "delivery_latitude",
            "delivery_location_longitude": "delivery_longitude",
            "time_orderd": "order_time",
            "time_order_picked": "order_picked_time",
            "weatherconditions": "weather",
            "road_traffic_density": "traffic",
            "city": "city_type",
            "time_taken(min)": "time_taken"
        },axis=1)
    )

# %%
#Change column names
df = change_column_names(df)

# %%
df.head()
# Out:
#         id          rider_id age ratings  restaurant_latitude  \
# 0  0x4607    INDORES13DEL02   37     4.9            22.745049
# 1  0xb379    BANGRES18DEL02   34     4.5            12.913041
# 2  0x5d6d    BANGRES19DEL01   23     4.4            12.914264
# 3  0x7a6a   COIMBRES13DEL02   38     4.7            11.003669
# 4  0x70a2    CHENRES12DEL01   32     4.6            12.972793
#
#    restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 0             75.892471          22.765049           75.912471  19-03-2022
# 1             77.683237          13.043041           77.813237  25-03-2022
# 2             77.678400          12.924264           77.688400  19-03-2022
# 3             76.976494          11.053669           77.026494  05-04-2022
# 4             80.249982          13.012793           80.289982  26-03-2022
#
#   order_time order_picked_time                weather  traffic  \
# 0   11:30:00          11:45:00       conditions Sunny    High
# ...

# %%
# check for duplicate rows
df.drop(columns=["id","rider_id"]).duplicated().sum()
# Out:
# np.int64(0)

# %%
# unique items in ID column
print(f"The number of unique IDs are {df['id'].nunique()}")
# Out:
# The number of unique IDs are 45593

# %%
df['rider_id'].nunique() #The data contains 1320 unique riders
# Out:
# 1320

# %%
df['rider_id'].value_counts()
# Out:
# rider_id
# PUNERES01DEL01       67
# JAPRES11DEL02        67
# VADRES08DEL02        66
# RANCHIRES02DEL01     66
# HYDRES04DEL02        66
#                      ..
# BHPRES15DEL03         7
# GOARES01DEL03         7
# KOLRES09DEL03         6
# KOCRES16DEL03         6
# BHPRES010DEL03        5
# Name: count, Length: 1320, dtype: int64

# %%
# extract city name out of rider id
df['rider_id'].str.split("RES").str.get(0).rename("City_Name")
# Out:
# 0          INDO
# 1          BANG
# 2          BANG
# 3         COIMB
# 4          CHEN
#           ...
# 45588       JAP
# 45589       AGR
# 45590      CHEN
# 45591     COIMB
# 45592    RANCHI
# Name: City_Name, Length: 45593, dtype: object

# %%
df['age'].astype(float).describe()
# Out:
# count    43739.000000
# mean        29.567137
# std          5.815155
# min         15.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         50.000000
# Name: age, dtype: float64

# %% [markdown]
# <span style="background-color:#1f2937; color:#fbbf24; padding:4px 10px; border-radius:999px;">
# Minimum Rider age of 15 is concerning
# </span>

# %%
sns.boxplot(df['age'].astype(float))
# Out:
# <Axes: ylabel='age'>

# %%
# rows of data where rider age is less than 18(minor)
minors_data = df.loc[df['age'].astype(float)<18]

# %%
minors_data.head()
# Out:
#           id          rider_id age ratings  restaurant_latitude  \
# 2387  0x564     JAPRES15DEL03   15       1           -26.891191
# 2905  0xcd0   INDORES010DEL03   15       1            22.750040
# 2951  0x91a     SURRES17DEL03   15       1            21.149569
# 5902  0x474    CHENRES15DEL03   15       1            13.026286
# 9156  0x73f    BANGRES05DEL01   15       1            12.970324
#
#       restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 2387             75.802083          26.981191           75.892083  12-03-2022
# 2905             75.902847          22.810040           75.962847  03-04-2022
# 2951             72.772697          21.209569           72.832697  21-03-2022
# 5902             80.275235          13.056286           80.305235  11-03-2022
# 9156             77.645748          13.080324           77.755748  25-03-2022
#
#      order_time order_picked_time         weather traffic  vehicle_condition  \
# ...

# %% [markdown]
# ### 🔍 Observations
#
# - <span style="color:#f87171;">The star ratings of all riders are <b>1</b>, indicating invalid or corrupted rating data.</span>
#
# - <span style="color:#fb923c;">The vehicle condition for these riders is reported as <b>very bad</b>, which is highly unusual across all records.</span>
#
# - <span style="color:#facc15;">Weather and road traffic condition data are completely <b>missing</b> for these entries.</span>
#
# - <span style="color:#ef4444;">The age of all riders is <b>15</b>, which is below the legally permissible driving age.</span>
#
# - <span style="color:#fb7185;">Latitude and longitude values are <b>negative</b>, which is invalid for India as it lies north of the equator and east of the prime meridian.</span>
#
# - <span style="color:#a3a3a3;">`Given the extent of missing, inconsistent, and logically incorrect values, <b>removing these records</b> is more appropriate than attempting to fix them.`</span>

# %%
# rows of minors
minor_index = minors_data.index.tolist()
len(minor_index)
# Out:
# 38

# %%
df['ratings'].astype(float).describe() #6 Star rating is possibly a data error
# Out:
# count    43685.000000
# mean         4.633780
# std          0.334716
# min          1.000000
# 25%          4.500000
# 50%          4.700000
# 75%          4.900000
# max          6.000000
# Name: ratings, dtype: float64

# %%
sns.boxplot(df['ratings'].astype(float))
# Out:
# <Axes: ylabel='ratings'>

# %%
df['ratings'].value_counts()
# Out:
# ratings
# 4.8     7148
# 4.7     7142
# 4.9     7041
# 4.6     6940
# 5       3996
# 4.5     3303
# NaN     1908
# 4.1     1430
# 4.2     1418
# 4.3     1409
# 4.4     1361
# 4       1077
# 3.5      249
# 3.8      228
# 3.7      225
# 3.6      207
# 3.9      197
# 6         53
# 1         38
# 3.4       32
# 3.1       29
# 3.2       29
# 3.3       25
# 2.6       22
# 2.7       22
# 2.5       20
# 2.8       19
# 2.9       19
# 3          6
# Name: count, dtype: int64

# %%
df[df['ratings'].astype(float)==1]
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 2387    0x564      JAPRES15DEL03   15       1           -26.891191
# 2905    0xcd0    INDORES010DEL03   15       1            22.750040
# 2951    0x91a      SURRES17DEL03   15       1            21.149569
# 5902    0x474     CHENRES15DEL03   15       1            13.026286
# 9156    0x73f     BANGRES05DEL01   15       1            12.970324
# 10900  0x1b49      MUMRES14DEL02   15       1            19.181300
# 11125   0x40b      SURRES12DEL01   15       1           -21.183434
# 12093   0x523     INDORES03DEL02   15       1            22.751857
# 15124  0x18b0   RANCHIRES02DEL01   15       1             0.000000
# 15927   0x550     CHENRES08DEL02   15       1            13.022394
# 16084   0x58c      MUMRES02DEL01   15       1           -19.221315
# 16462   0xe4c      MYSRES05DEL03   15       1            12.323978
# 21222   0x3fc     BANGRES16DEL02   15       1            13.029198
# ...

# %%
df[df['ratings'].astype(float)==6]
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 3586    0x46d     BANGRES05DEL01   50       6           -12.970324
# 4714    0x493      HYDRES17DEL01   50       6           -17.451976
# 5169    0x4f2      JAPRES08DEL01   50       6           -26.910262
# 5362    0x430     BANGRES19DEL01   50       6            12.914264
# 5651   0xbef1      AGRRES13DEL02   50       6           -27.159795
# 6394    0x427      JAPRES06DEL02   50       6            26.911927
# 7031    0x3eb      MYSRES15DEL02   50       6           -12.352058
# 7681    0xd42      VADRES09DEL01   50       6             0.000000
# 9499    0x3f0    BANGRES010DEL01   50       6            12.933298
# 9535    0x3ef   RANCHIRES13DEL01   50       6           -23.374989
# 10100   0x5b0      MYSRES04DEL01   50       6            12.308500
# 10737  0xbffc      DEHRES18DEL02   50       6             0.000000
# 12297   0x940      SURRES02DEL02   50       6            21.186608
# ...

# %% [markdown]
# ### 🔍 Rating Anomalies – Observations
#
# - <span style="color:#f87171;">🔴 The <b>Minors</b> data consistently shows rider ratings of <b>1</b>, which appears anomalous when compared to the overall ratings distribution.</span>
#
# - <span style="color:#fb923c;">🟠 A rating value of <b>6</b> is present in the dataset, which is invalid since the maximum permissible rating is <b>5</b>.</span>
#
# - <span style="color:#ef4444;">🔴 The rating value of <b>6</b> occurs only for riders aged <b>50</b>, which further strengthens the concern of data inconsistency rather than a legitimate edge case.</span>
#
# - <span style="color:#facc15;">🟡 These irregular patterns indicate underlying data quality issues and <b>must be investigated</b> to identify the root cause.</span>
#
# - <span style="color:#a3a3a3;">⚪ If the data is confirmed to be unreliable, actions such as <b>correcting</b> the values or <b>removing</b> the affected records should be considered.</span>

# %%
location_columns = df.columns[4:8].tolist()
location_columns
# Out:
# ['restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude']

# %%
location_subset = df.loc[:,location_columns]

# %%
location_subset.head()
# Out:
#    restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 0            22.745049             75.892471          22.765049
# 1            12.913041             77.683237          13.043041
# 2            12.914264             77.678400          12.924264
# 3            11.003669             76.976494          11.053669
# 4            12.972793             80.249982          13.012793
#
#    delivery_longitude
# 0           75.912471
# 1           77.813237
# 2           77.688400
# 3           77.026494
# 4           80.289982

# %% [markdown]
# ### 📍 Valid Latitude and Longitude Ranges (India)
#
# - <span style="color:#60a5fa;">🇮🇳 India lies to the <b>north of the equator</b>, between <b>6° 44′ N</b> and <b>35° 30′ N</b> latitude.</span>
#
# - <span style="color:#34d399;">🌏 India is located to the <b>east of the Prime Meridian</b>, between <b>68° 7′ E</b> and <b>97° 25′ E</b> longitude.</span>

# %%
# statistical analysis
location_subset.describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         45593.000000          45593.000000       45593.000000
# mean             17.017729             70.231332          17.465186
# std               8.185109             22.883647           7.335122
# min             -30.905562            -88.366217           0.010000
# 25%              12.933284             73.170000          12.988453
# 50%              18.546947             75.898497          18.633934
# 75%              22.728163             78.044095          22.785049
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        45593.000000
# mean            70.845702
# std             21.118812
# min              0.010000
# 25%             73.280000
# 50%             76.002574
# 75%             78.107044
# max             88.563452

# %%
# set the lower bound limits for the lat and long
lower_bound_lat = 6.44
lower_bound_long = 68.70

# %%
# rows of data where latitude and longitude values are below the bounds
df.loc[
    (df['restaurant_latitude'] < lower_bound_lat) |
    (df['restaurant_longitude'] < lower_bound_long) |
    (df['delivery_latitude'] < lower_bound_lat) |
    (df['delivery_longitude'] < lower_bound_long)
].sample(50)
# Out:
#             id           rider_id   age ratings  restaurant_latitude  \
# 42137  0x4f35   RANCHIRES02DEL03     27     4.8             0.000000
# 33803  0xc862      AGRRES06DEL03     25     4.9             0.000000
# 22325  0xcf01      BHPRES14DEL02     26     4.8             0.000000
# 24237   0x420      SURRES13DEL01     50       6           -21.170096
# 11526  0xda84      DEHRES02DEL01     28       5             0.000000
# 17085  0x5ec2      VADRES02DEL02     27     4.4             0.000000
# 583     0x5af      MYSRES16DEL01   NaN     NaN            -12.316967
# 14666  0x7358      VADRES02DEL01     37     4.9             0.000000
# 8578   0x75ec   RANCHIRES03DEL02     36     4.6             0.000000
# 2971   0xa6b6      VADRES07DEL01     20     4.2             0.000000
# 5717   0x4bee      VADRES12DEL03     35     4.9             0.000000
# 6269   0x63bb   RANCHIRES03DEL03     36     4.8             0.000000
# 10585  0x6d3d   RANCHIRES12DEL02     33     4.6             0.000000
# ...

# %%
location_subset[location_subset['restaurant_latitude'] < lower_bound_lat]
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 33                     0.0                   0.0               0.11
# 52                     0.0                   0.0               0.03
# 57                     0.0                   0.0               0.08
# 59                     0.0                   0.0               0.06
# 67                     0.0                   0.0               0.02
# ...                    ...                   ...                ...
# 45569                  0.0                   0.0               0.07
# 45576                  0.0                   0.0               0.13
# 45577                  0.0                   0.0               0.09
# 45579                  0.0                   0.0               0.05
# 45589                  0.0                   0.0               0.07
#
#        delivery_longitude
# 33                   0.11
# 52                   0.03
# 57                   0.08
# 59                   0.06
# ...

# %%
# number of rows in data where lat long are erroneous

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].shape[0]
# Out:
# 4071

# %% [markdown]
# <span style="background-color:#1f2937; color:#fbbf24; padding:4px 10px; border-radius:999px;">
# There are 4071 rows in the data where the lat long columns are messy
# </span>

# %%
#statistical summary of problematic rows where lat long is below the country's geographical limits
location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count          4071.000000           4071.000000        4071.000000
# mean             -2.149416              2.068601           2.212538
# std               6.537913             25.270676           6.538283
# min             -30.905562            -88.366217           0.010000
# 25%               0.000000              0.000000           0.040000
# 50%               0.000000              0.000000           0.070000
# 75%               0.000000              0.000000           0.110000
# max               0.000000             88.433452          31.045562
#
#        delivery_longitude
# count         4071.000000
# mean             8.299885
# std             23.980011
# min              0.010000
# 25%              0.040000
# 50%              0.070000
# 75%              0.110000
# max             88.523452

# %%
# boxplots for all the anomalies
location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].plot(kind="box")

plt.xticks(rotation=45)
# Out:
# (array([1, 2, 3, 4]),
#  [Text(1, 0, 'restaurant_latitude'),
#   Text(2, 0, 'restaurant_longitude'),
#   Text(3, 0, 'delivery_latitude'),
#   Text(4, 0, 'delivery_longitude')])

# %% [markdown]
# ### 📐 Handling Negative Latitude & Longitude Values
#
# - <span style="color:#34d399;">🟢 Negative latitude and longitude values can be <b>corrected by taking their absolute values</b>, as the magnitude represents the correct geographic position.</span>
#
# - <span style="color:#facc15;">🟡 During distance calculations, these erroneous coordinate values can be <b>temporarily assigned as null</b> to avoid incorrect distance computation.</span>
#
# - <span style="color:#60a5fa;">🔵 The missing coordinates can then be <b>imputed using advanced imputation techniques</b> to preserve data integrity and minimize information loss.</span>

# %%
location_subset.abs().plot(kind='box')
ax = plt.gca()

ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(1, 0, 'restaurant_latitude'),
#  Text(2, 0, 'restaurant_longitude'),
#  Text(3, 0, 'delivery_latitude'),
#  Text(4, 0, 'delivery_longitude')]

# %%
# number of rows after taking absolute values

(
    location_subset.abs()
    .loc[lambda df_:
        (df_['restaurant_latitude'] < lower_bound_lat) |
        (df_['restaurant_longitude'] < lower_bound_long) |
        (df_['delivery_latitude'] < lower_bound_lat) |
        (df_['delivery_longitude'] < lower_bound_long)]
    .shape[0]

)
# Out:
# 3640

# %%
# lat long values less than 1
location_subset.abs().loc[lambda df_:
                        (df_['restaurant_latitude'] < 1) |
                        (df_['restaurant_longitude'] < 1) |
                        (df_['delivery_latitude'] < 1) |
                        (df_['delivery_longitude'] < 1)]
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 33                     0.0                   0.0               0.11
# 52                     0.0                   0.0               0.03
# 57                     0.0                   0.0               0.08
# 59                     0.0                   0.0               0.06
# 67                     0.0                   0.0               0.02
# ...                    ...                   ...                ...
# 45569                  0.0                   0.0               0.07
# 45576                  0.0                   0.0               0.13
# 45577                  0.0                   0.0               0.09
# 45579                  0.0                   0.0               0.05
# 45589                  0.0                   0.0               0.07
#
#        delivery_longitude
# 33                   0.11
# 52                   0.03
# 57                   0.08
# 59                   0.06
# ...

# %% [markdown]
# <span style="background-color:#1f2937; color:#fbbf24; padding:4px 10px; border-radius:999px;">
# All the messy lat long values are less than 1
# </span>

# %%
def clean_lat_long(data:pd.DataFrame,threshold=1):
    location_columns = location_subset.columns.tolist()

    return (
        data.assign(**{
            col: (
                np.where(data[col]<threshold,np.nan,data[col].values)
            )
            for col in location_columns
        })
    )

# %%
clean_lat_long(df).isna().sum()
# Out:
# id                         0
# rider_id                   0
# age                        0
# ratings                    0
# restaurant_latitude     4071
# restaurant_longitude    3802
# delivery_latitude       3640
# delivery_longitude      3640
# order_date                 0
# order_time                 0
# order_picked_time          0
# weather                    0
# traffic                    0
# vehicle_condition          0
# type_of_order              0
# type_of_vehicle            0
# multiple_deliveries        0
# festival                   0
# city_type                  0
# time_taken                 0
# dtype: int64

# %%
#OrderDate
df['order_date'].unique()
# Out:
# array(['19-03-2022', '25-03-2022', '05-04-2022', '26-03-2022',
#        '11-03-2022', '04-03-2022', '14-03-2022', '20-03-2022',
#        '12-02-2022', '13-02-2022', '14-02-2022', '02-04-2022',
#        '01-03-2022', '16-03-2022', '15-02-2022', '10-03-2022',
#        '27-03-2022', '12-03-2022', '01-04-2022', '05-03-2022',
#        '11-02-2022', '08-03-2022', '03-04-2022', '30-03-2022',
#        '28-03-2022', '18-03-2022', '06-04-2022', '04-04-2022',
#        '24-03-2022', '09-03-2022', '02-03-2022', '13-03-2022',
#        '29-03-2022', '31-03-2022', '17-03-2022', '07-03-2022',
#        '15-03-2022', '16-02-2022', '03-03-2022', '18-02-2022',
#        '23-03-2022', '17-02-2022', '06-03-2022', '21-03-2022'],
#       dtype=object)

# %%
#DateRange
order_date = pd.to_datetime(df['order_date'],dayfirst=True)

# %%
order_date.max() - order_date.min()
# Out:
# Timedelta('54 days 00:00:00')

# %%
# min and maximum dates
order_date.agg(["min","max"]).set_axis(["start","end"],axis=0)
# Out:
# start   2022-02-11
# end     2022-04-06
# Name: order_date, dtype: datetime64[ns]

# %%
# extract day, day name, month and year
def extract_datetime_features(ser):
    date_col = pd.to_datetime(ser,dayfirst=True)

    return (
        pd.DataFrame(
            {
                "day": date_col.dt.day,
                "month": date_col.dt.month,
                "year": date_col.dt.year,
                "day_of_week": date_col.dt.day_name(),
                "is_weekend": date_col.dt.day_name().isin(["Saturday","Sunday"]).astype(int)
            }
        ))

# %%
extract_datetime_features(df['order_date'])
# Out:
#        day  month  year day_of_week  is_weekend
# 0       19      3  2022    Saturday           1
# 1       25      3  2022      Friday           0
# 2       19      3  2022    Saturday           1
# 3        5      4  2022     Tuesday           0
# 4       26      3  2022    Saturday           1
# ...    ...    ...   ...         ...         ...
# 45588   24      3  2022    Thursday           0
# 45589   16      2  2022   Wednesday           0
# 45590   11      3  2022      Friday           0
# 45591    7      3  2022      Monday           0
# 45592    2      3  2022   Wednesday           0
#
# [45593 rows x 5 columns]

# %%
#Order time and Order picked time
order_time_hr = pd.to_datetime(df.replace("NaN ",np.nan)['order_time'],format='mixed').dt.hour

# %%
def time_of_day(ser):
    time_col = pd.to_datetime(ser,format='mixed').dt.hour

    return(
        np.select(condlist=[(ser.between(6,12,inclusive='left')),
                            (ser.between(12,17,inclusive='left')),
                            (ser.between(17,20,inclusive='left')),
                            (ser.between(20,24,inclusive='left'))],
                  choicelist=["morning","afternoon","evening","night"],
                  default="after_midnight")
    )

# %%
time_of_day(order_time_hr)
# Out:
# array(['morning', 'evening', 'morning', ..., 'night', 'afternoon',
#        'evening'], dtype='<U14')

# %%
time_subset = df.loc[:,["order_time","order_picked_time"]]
time_subset
# Out:
#       order_time order_picked_time
# 0       11:30:00          11:45:00
# 1       19:45:00          19:50:00
# 2       08:30:00          08:45:00
# 3       18:00:00          18:10:00
# 4       13:30:00          13:45:00
# ...          ...               ...
# 45588   11:35:00          11:45:00
# 45589   19:55:00          20:10:00
# 45590   23:50:00          00:05:00
# 45591   13:35:00          13:40:00
# 45592   17:10:00          17:15:00
#
# [45593 rows x 2 columns]

# %%
# calculate the pickup time

(
    time_subset
    .assign(**{
        col: pd.to_datetime(time_subset[col].replace("NaN ",np.nan).dropna(),format="mixed")
        for col in time_subset.columns.tolist()}
    )
    .assign(
        pickup_time = lambda x: (x['order_picked_time'] - x['order_time']).dt.seconds / 60,
        order_time_hour = lambda x: x['order_time'].dt.hour,
        order_time_of_day = lambda x: x['order_time_hour'].pipe(time_of_day)
    )
    .drop(columns=["order_time","order_picked_time"])
)
# Out:
#        pickup_time  order_time_hour order_time_of_day
# 0             15.0             11.0           morning
# 1              5.0             19.0           evening
# 2             15.0              8.0           morning
# 3             10.0             18.0           evening
# 4             15.0             13.0         afternoon
# ...            ...              ...               ...
# 45588         10.0             11.0           morning
# 45589         15.0             19.0           evening
# 45590         15.0             23.0             night
# 45591          5.0             13.0         afternoon
# 45592          5.0             17.0           evening
#
# [45593 rows x 3 columns]

# %%
#Weather
df['weather'].value_counts()
# Out:
# weather
# conditions Fog           7654
# conditions Stormy        7586
# conditions Cloudy        7536
# conditions Sandstorms    7495
# conditions Windy         7422
# conditions Sunny         7284
# conditions NaN            616
# Name: count, dtype: int64

# %%
# unique values
df['weather'].unique()
# Out:
# array(['conditions Sunny', 'conditions Stormy', 'conditions Sandstorms',
#        'conditions Cloudy', 'conditions Fog', 'conditions Windy',
#        'conditions NaN'], dtype=object)

# %%
# remove conditions from values
(
    df['weather']
    .str.replace("conditions ","")
    .unique()
)
# Out:
# array(['Sunny', 'Stormy', 'Sandstorms', 'Cloudy', 'Fog', 'Windy', 'NaN'],
#       dtype=object)

# %%
#Traffic
df['traffic'].value_counts()
# Out:
# traffic
# Low        15477
# Jam        14143
# Medium     10947
# High        4425
# NaN          601
# Name: count, dtype: int64

# %%
# unique values
df['traffic'].unique()
# Out:
# array(['High ', 'Jam ', 'Low ', 'Medium ', 'NaN '], dtype=object)

# %%
df['traffic'].replace("NaN ",np.nan).str.rstrip().str.lower().unique()
# Out:
# array(['high', 'jam', 'low', 'medium', nan], dtype=object)

# %%
#Vehicle condition
np.sort(df['vehicle_condition'].unique())
# Out:
# array([0, 1, 2, 3])

# %%
# Type of Order
df['type_of_order'].value_counts()
# Out:
# type_of_order
# Snack      11533
# Meal       11458
# Drinks     11322
# Buffet     11280
# Name: count, dtype: int64

# %%
#Type of Vehicle
df['type_of_vehicle'].value_counts()
# Out:
# type_of_vehicle
# motorcycle           26435
# scooter              15276
# electric_scooter      3814
# bicycle                 68
# Name: count, dtype: int64

# %%
#Multiple Deliveries
df['multiple_deliveries'].unique()
# Out:
# array(['0', '1', '3', 'NaN ', '2'], dtype=object)

# %%
# make the column as integer

(
    df['multiple_deliveries']
    .replace("NaN ",np.nan)
    .astype(float)
    .unique()
)
# Out:
# array([ 0.,  1.,  3., nan,  2.])

# %%
#Festival
df['festival'].unique()
# Out:
# array(['No ', 'Yes ', 'NaN '], dtype=object)

# %%
(
    df['festival']
    .replace("NaN ",np.nan)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
#City Type
df['city_type'].unique()
# Out:
# array(['Urban ', 'Metropolitian ', 'Semi-Urban ', 'NaN '], dtype=object)

# %%
(
    df['city_type']
    .replace("NaN ",np.nan)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['urban', 'metropolitian', 'semi-urban', nan], dtype=object)

# %% [markdown]
# ### 🏙️ City Category Meanings
#
# - <span style="color:#60a5fa;">🔵 <b>Urban</b> – Well-developed city areas with high population density and established infrastructure.</span>
#
# - <span style="color:#34d399;">🟢 <b>Metropolitian</b> – Large metropolitan cities with advanced infrastructure, heavy traffic, and high commercial activity.</span>
#
# - <span style="color:#facc15;">🟡 <b>Semi-Urban</b> – Transitional areas between urban and rural regions with moderate development.</span>
#
# - <span style="color:#f87171;">🔴 <b>NaN</b> – Missing or unavailable city category information.</span>

# %%
#Time Taken
df['time_taken'].str.replace("(min) ","").astype(int)
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45588    32
# 45589    36
# 45590    16
# 45591    26
# 45592    36
# Name: time_taken, Length: 45593, dtype: int64

# %% [markdown]
# ## OverAll Cleaning Function

# %%
six_star_data = df[df['ratings']=='6']

# %%
six_star_index = six_star_data.index.tolist()
len(six_star_index)
# Out:
# 53

# %%
df.columns
# Out:
# Index(['id', 'rider_id', 'age', 'ratings', 'restaurant_latitude',
#        'restaurant_longitude', 'delivery_latitude', 'delivery_longitude',
#        'order_date', 'order_time', 'order_picked_time', 'weather', 'traffic',
#        'vehicle_condition', 'type_of_order', 'type_of_vehicle',
#        'multiple_deliveries', 'festival', 'city_type', 'time_taken'],
#       dtype='object')

# %%
def data_cleaning(data: pd.DataFrame):

    return (
        data
        .drop(columns='id')
        .drop(index=minor_index)
        .drop(index=six_star_index)
        .replace("NaN ",np.nan)
        .assign(
            city_name = lambda x : x['rider_id'].str.split('RES').str.get(0),
            age = lambda x: x['age'].astype(float),
            ratings = lambda x: x['ratings'].astype(float),
            restaurment_latitude = lambda x: x['restaurant_latitude'].abs(),
            restaurment_longitude = lambda x: x['restaurant_longitude'].abs(),
            delivery_latitude = lambda x: x['delivery_latitude'].abs(),
            delivery_longitude = lambda x: x['delivery_longitude'].abs(),
            order_date = lambda x: pd.to_datetime(x['order_date'],dayfirst=True),
            order_day = lambda x: x['order_date'].dt.day,
            order_month = lambda x: x['order_date'].dt.month,
            order_day_of_week = lambda x: x['order_date'].dt.day_name().str.lower(),
            is_weekend = lambda x: (x['order_date'].dt.day_name().isin(["Saturday","Sunday"]).astype(int)),
            order_time = lambda x: pd.to_datetime(x['order_time'],format='mixed'),
            order_picked_time = lambda x: pd.to_datetime(x['order_picked_time'],format='mixed'),
            pickup_time_minutes = lambda x: ((x['order_picked_time'] - x['order_time']).dt.seconds / 60),
            order_time_hour = lambda x: x['order_time'].dt.hour,
            order_time_of_day = lambda x: (x['order_time_hour'].pipe(time_of_day)),
            weather = lambda x: (x['weather'].str.replace("conditions ","").str.lower().replace("nan",np.nan)),
            traffic = lambda x:x['traffic'].str.rstrip().str.lower(),
            type_of_order = lambda x: x['type_of_order'].str.rstrip().str.lower(),
            type_of_vehicle = lambda x: x['type_of_vehicle'].str.rstrip().str.lower(),
            festival = lambda x: x['festival'].str.rstrip().str.lower(),
            city_type = lambda x: x['city_type'].str.rstrip().str.lower(),
            multiple_deliveries=lambda x: x['multiple_deliveries'].astype(float),
            time_taken = lambda x: (x['time_taken'].str.replace("(min) ","").astype(int))
        .drop(columns=["order_time","order_picked_time"])
            
        )
    )

# %%
data_cleaning(df)
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45588     JAPRES04DEL01   30.0      4.8            26.902328
# 45589     AGRRES16DEL01   21.0      4.6             0.000000
# 45590    CHENRES08DEL03   30.0      4.9            13.022394
# 45591   COIMBRES11DEL01   20.0      4.7            11.001753
# 45592  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 0                 75.892471          22.765049           75.912471 2022-03-19
# ...

# %%
location_subset.columns.tolist()
# Out:
# ['restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude']

# %%
def calculate_haversine_distance(df):

    location_columns = location_subset.columns.tolist()
    lat1 = df[location_columns[0]]
    lon1 = df[location_columns[1]]
    lat2 = df[location_columns[2]]
    lon2 = df[location_columns[3]]
    #Convert degrees to radians
    lon1,lat1,lon2,lat2 = map(np.radians,[lon1,lat1,lon2,lat2])
    #Find the difference between points
    dlon = lon2-lon1
    dlat = lat2 - lat1
    #This formula helps us measure distance on a round Earth (Haversine formula)
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon /2.0)**2
    #Convert formula output into angl
    c = 2 * np.arcsin(np.sqrt(a))
    #Convert angle into kilometers (6371 km is the radius of Earth)
    distance = 6371 * c

    return (
        df.assign(distance=distance)
    )

# %%
# add more data cleaning steps

cleaned_data = (
                df.pipe(data_cleaning)
                .pipe(clean_lat_long)
                .pipe(calculate_haversine_distance)
                )

cleaned_data
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45588     JAPRES04DEL01   30.0      4.8            26.902328
# 45589     AGRRES16DEL01   21.0      4.6                  NaN
# 45590    CHENRES08DEL03   30.0      4.9            13.022394
# 45591   COIMBRES11DEL01   20.0      4.7            11.001753
# 45592  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 0                 75.892471          22.765049           75.912471 2022-03-19
# ...

# %% [markdown]
# ## Validate Data Cleaning

# %%
# age column
cleaned_data['age'].agg(["min","max"])
# Out:
# min    20.0
# max    39.0
# Name: age, dtype: float64

# %%
# ratings column
cleaned_data['ratings'].agg(["min","max"])
# Out:
# min    2.5
# max    5.0
# Name: ratings, dtype: float64

# %%
# location columns

cleaned_data[location_columns].plot(kind="box")

plt.xticks(rotation=45)

display(cleaned_data[location_columns].describe())
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         41473.000000          41737.000000       41872.000000
# mean             18.898979             76.920513          18.977356
# std               5.460570              3.503334           5.469056
# min               9.957144             72.768726           9.967144
# 25%              12.986047             73.897902          13.065996
# 50%              19.065838             76.618203          19.124049
# 75%              22.751234             78.368855          22.820040
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        41872.000000
# mean            76.985325
# std              3.503260
# min             72.778726
# 25%             73.940327
# 50%             76.662620
# 75%             78.405467
# max             88.563452

# %%
# values in categorical columns

cat_cols = cleaned_data.select_dtypes(include="object").columns.tolist()
for col in cat_cols:
    print(f"For {col} unique values are: {cleaned_data[col].unique()}",end="\n\n")
# Out:
# For rider_id unique values are: ['INDORES13DEL02 ' 'BANGRES18DEL02 ' 'BANGRES19DEL01 ' ...
#  'KOCRES04DEL01 ' 'BHPRES06DEL03 ' 'GOARES03DEL03 ']
#
# For weather unique values are: ['sunny' 'stormy' 'sandstorms' 'cloudy' 'fog' 'windy' nan]
#
# For traffic unique values are: ['high' 'jam' 'low' 'medium' nan]
#
# For type_of_order unique values are: ['snack' 'drinks' 'buffet' 'meal']
#
# For type_of_vehicle unique values are: ['motorcycle' 'scooter' 'electric_scooter' 'bicycle']
#
# For festival unique values are: ['no' 'yes' nan]
#
# For city_type unique values are: ['urban' 'metropolitian' 'semi-urban' nan]
#
# For city_name unique values are: ['INDO' 'BANG' 'COIMB' 'CHEN' 'HYD' 'RANCHI' 'MYS' 'DEH' 'KOC' 'PUNE'
#  'LUDH' 'KNP' 'MUM' 'KOL' 'JAP' 'SUR' 'GOA' 'AURG' 'AGR' 'VAD' 'ALH' 'BHP']
#
# For order_day_of_week unique values are: ['saturday' 'friday' 'tuesday' 'monday' 'sunday' 'wednesday' 'thursday']
#
# ...

# %%
# bar plot of missing values
msno.bar(cleaned_data)
# Out:
# <Axes: >

# %%
# matrix of missing values

msno.matrix(cleaned_data)
# Out:
# <Axes: >

# %%
# correlation chart of missing values
msno.heatmap(cleaned_data)
# Out:
# <Axes: >

# %% [markdown]
# ### 🔗 Correlation Analysis – Summary
#
# - <span style="color:#60a5fa;"><b>Age and Ratings</b> show a very strong positive correlation, indicating that these rider-related attributes tend to increase together.</span>
#
# - <span style="color:#34d399;"><b>Restaurant and Delivery Coordinates</b> (latitude & longitude) are highly correlated with each other, which is expected since locations within the same geographic region follow similar spatial patterns.</span>
#
# - <span style="color:#a78bfa;"><b>Order Time, Pickup Time, and Order Hour</b> are strongly correlated, confirming that these time-derived features are logically dependent.</span>
#
# - <span style="color:#facc15;"><b>Weather and Traffic Conditions</b> exhibit moderate correlation, suggesting they may be influenced by similar external factors but are not fully dependent.</span>
#
# - <span style="color:#fb923c;"><b>Distance</b> shows strong correlation with latitude and longitude values, validating the correctness of the distance calculation using geographic coordinates.</span>
#
# - <span style="color:#9ca3af;"><b>Festival, City Type, and Multiple Deliveries</b> show weak or negligible correlation with most numerical features, indicating limited linear relationships.</span>

# %%
# save the cleaned data
cleaned_data.to_csv("cleaned_data.csv",index=False)
